# %% [markdown]
# # Web Scraping - Indeed.com
# General steps for Web Scraping
# 1. Check whether the website allows web scraping
# 2. Obtain the source code (HTML File) by using the website URL
# 3. Download the website content
# 4. Parse the content using keywords tags for elements of interest
# 5. Extract relevant data/features
# 6. Organize raw data in structured format (e.g., CSV)

# %% [markdown]
# ### Import Dependencies

# %%
import pandas as pd
from bs4 import BeautifulSoup
from datetime import datetime
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.firefox.options import Options

options = Options()
options.binary_location = 'C:\\Program Files\\Mozilla Firefox\\firefox.exe'

# %% [markdown]
# ### Path to webdriver (Firefox, Chrome)

# %%
# Ensure that the driver path is correct before running this script.
# Microsoft Windows
driver_path = "C:/Users/shiva/Desktop/UofT/Term3-Fall2022/APS1624/Assignment 3/geckodriver.exe"
# Linux
#driver_path = "./drivers/linux/geckodriver"
driver = webdriver.Firefox(executable_path=driver_path, options=options)
# Out:
# C:\Users\shiva\AppData\Local\Temp\ipykernel_28212\3176788480.py:6: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Firefox(executable_path=driver_path, options=options)

# %% [markdown]
# ### Define position and location

# %%
## Enter a job position
position = "data scientist"
## Enter a location (City, State or Zip or remote)
locations = "remote"

def get_url(position, location):
    url_template = "https://www.indeed.com/jobs?q={}&l={}"
    url = url_template.format(position, location)
    return url

url = get_url(position, locations)
dataframe = pd.DataFrame(columns=["Title", "Company", "Location", "Rating", "Date", "Salary", "Description", "Links"])

# %% [markdown]
# ### Scrape job postings

# %%
## Number of postings to scrape
postings = 100

jn=0
for i in range(0, postings, 10):
    driver.get(url + "&start=" + str(i))
    driver.implicitly_wait(3)

    jobs = driver.find_elements(By.CLASS_NAME, 'job_seen_beacon')

    for job in jobs:
        result_html = job.get_attribute('innerHTML')
        soup = BeautifulSoup(result_html, 'html.parser')
        
        jn += 1
        
        liens = job.find_elements(By.TAG_NAME, "a")
        links = liens[0].get_attribute("href")
        
        title = soup.select('.jobTitle')[0].get_text().strip()
        company = soup.select('.companyName')[0].get_text().strip()
        location = soup.select('.companyLocation')[0].get_text().strip()
        try:
            salary = soup.select('.salary-snippet-container')[0].get_text().strip()
        except:
            salary = 'NaN'
        try:
            rating = soup.select('.ratingNumber')[0].get_text().strip()
        except:
            rating = 'NaN'
        try:
            date = soup.select('.date')[0].get_text().strip()
        except:
            date = 'NaN'
        try:
            description = soup.select('.job-snippet')[0].get_text().strip()
        except:
            description = ''
       
        dataframe = pd.concat([dataframe, pd.DataFrame([{'Title': title,
                                          "Company": company,
                                          'Location': location,
                                          'Rating': rating,
                                          'Date': date,
                                          "Salary": salary,
                                          "Description": description,
                                          "Links": links}])], ignore_index=True)
        print("Job number {0:4d} added - {1:s}".format(jn,title))
# Out:
# Job number    1 added - Data Scientist
# Job number    2 added - Data Scientist, Marketing & Online (Remote)
# Job number    3 added - Data Scientist - NLP
# Job number    4 added - Data Scientist - Telecommute
# Job number    5 added - Jr. Data Scientist
# Job number    6 added - Jr. Data Scientist
# Job number    7 added - Data Scientist
# Job number    8 added - Data Analyst
# Job number    9 added - Customer Data Scientist
# Job number   10 added - Junior Machine Learning Engineer
# Job number   11 added - Senior Data Scientist
# Job number   12 added - Principal Operations Research Scientist - Network Planning/Future Transportation (Optimization, Machine Learning) Remote or HQ
# Job number   13 added - Nurse Data Miner
# Job number   14 added - Data Scientist
# Job number   15 added - Data Scientist
# Job number   16 added - Nurse Data Miner
# Job number   17 added - Data Scientist
# Job number   18 added - Data Scientist (Remote)
# Job number   19 added - Data Scientist Co-Op (Spring 2023)
# Job number   20 added - Data Scientist, Analytics II #0000
# Job number   21 added - Junior Data Scientist
# Job number   22 added - Data Scientist, Baseball Research & Development
# Job number   23 added - Jr. Data Scientist
# Job number   24 added - Data Scientist
# Job number   25 added - Data Scientist
# Job number   26 added - Software Engineer - Machine Learning (Remote)
# Job number   27 added - Data Scientist
# Job number   28 added - Data Scientist
# Job number   29 added - Statistical Programmer
# Job number   30 added - Data Scientist or Bioinformatician (remote)
# Job number   31 added - Data Scientist
# Job number   32 added - Data Scientist
# Job number   33 added - Data Scientist, Product
# Job number   34 added - Data Scientist
# Job number   35 added - Data Scientist
# Job number   36 added - Statistician and Data Scientist, Junior
# Job number   37 added - Data Scientist
# Job number   38 added - Staff Data Scientist, Financial Crimes Technology
# Job number   39 added - (5) Data Analyst / Data Scientist
# Job number   40 added - Associate Data Scientist
# Job number   41 added - Data Scientist
# Job number   42 added - Data Science Product Owner (REMOTE)
# Job number   43 added - Software Engineer III, AI/ML Threat Predictions (Remote)
# Job number   44 added - Data Scientist
# Job number   45 added - Data Scientist
# Job number   46 added - Senior Data Scientist
# Job number   47 added - data engineer
# Job number   48 added - Staff Data Scientist - Search, Inference
# Job number   49 added - Data Science - General Interest - Talent Community
# Job number   50 added - Data Scientist
# Job number   51 added - Data Scientist
# Job number   52 added - Data Scientist
# Job number   53 added - Data Scientist/Applied Researcher
# Job number   54 added - Jr. Data Scientist
# Job number   55 added - Data Scientist
# Job number   56 added - Data Scientist (Virtual)
# Job number   57 added - Data Scientist
# Job number   58 added - Software Engineer III, AI/ML Threat Predictions (Remote)
# Job number   59 added - Sr. Clinical Data Scientist
# Job number   60 added - Data Scientist
# Job number   61 added - Data Analyst
# Job number   62 added - Data Scientist
# Job number   63 added - Data Scientist I
# Job number   64 added - Senior Product Data Scientist
# Job number   65 added - Data Scientist
# Job number   66 added - Data Scientist
# Job number   67 added - Data Scientist
# Job number   68 added - Data Scientist
# Job number   69 added - Data Scientist Co-Op (Spring 2023)
# Job number   70 added - Data Scientist
# Job number   71 added - Data Science & Analytics Leader, Member Product
# Job number   72 added - Software Engineer III, AI/ML Threat Predictions (Remote)
# Job number   73 added - Data Analyst
# Job number   74 added - Data Scientist
# Job number   75 added - Data Analyst (Remote)
# Job number   76 added - Machine Learning Engineer
# Job number   77 added - Data Scientist
# Job number   78 added - Data Scientist (NBA)
# Job number   79 added - People Analytics Data Scientist
# Job number   80 added - Remote Data Scientist - Credit Risk
# Job number   81 added - Data Scientist, Creator Promotion
# Job number   82 added - Machine Learning Engineer
# Job number   83 added - Data Scientist - Model Validator (REMOTE)
# Job number   84 added - Sr Clinical Data Analyst
# Job number   85 added - Data Scientist
# Job number   86 added - Senior Data Scientist - Inference, Payments
# Job number   87 added - Data Scientist
# Job number   88 added - Data Scientist, Tooling
# Job number   89 added - eComm Principal Data Scientist
# Job number   90 added - Software Engineer III, AI/ML Threat Predictions (Remote)
# Job number   91 added - Data Scientist (ALL LEVELS)
# Job number   92 added - Data Scientist - Shuzhao Li Lab
# Job number   93 added - Data Scientist
# Job number   94 added - Machine Learning Operations Engineer (Part-Time/Consulting)
# Job number   95 added - Data Scientist / Deep Learning Engineer
# Job number   96 added - Hiring for Data Scientist remote position :: Fulltime
# Job number   97 added - Data Scientist
# Job number   98 added - Data Scientist
# Job number   99 added - Data Scientist
# Job number  100 added - Data Scientist
# Job number  101 added - Senior Data Scientist - CDH - Remote
# Job number  102 added - Data Scientist
# Job number  103 added - Principal Data Scientist - CDH - Remote
# Job number  104 added - Actuarial Data Scientist
# Job number  105 added - Software Engineer III, AI/ML Threat Predictions (Remote)
# Job number  106 added - Data Scientist
# Job number  107 added - Data Scientist
# Job number  108 added - Data Scientist - Machine Learning Ops
# Job number  109 added - Data Scientist
# Job number  110 added - Data Visualization Specialist
# Job number  111 added - Data Scientist
# Job number  112 added - Data Scientist
# Job number  113 added - Data Scientist
# Job number  114 added - Data Scientist
# Job number  115 added - Data Analyst, Data Science
# Job number  116 added - Data Scientist
# Job number  117 added - Data Science/Analytics - New Graduate
# Job number  118 added - Data Scientist
# Job number  119 added - Data Scientist (AI/ML, AWS)
# Job number  120 added - Software Engineer III, AI/ML Threat Predictions (Remote)
# Job number  121 added - Remote Data Scientist
# Job number  122 added - Data Quality Engineer
# Job number  123 added - Data Science Associate (Remote)
# Job number  124 added - Machine Learning Engineer
# Job number  125 added - Sr Data Scientist
# Job number  126 added - Data Scientist
# Job number  127 added - Data Scientist | Remote-US
# Job number  128 added - Staff Data Scientist, ML Ops
# Job number  129 added - Network Data Scientist
# Job number  130 added - Data Scientist
# Job number  131 added - Data Scientist
# Job number  132 added - Cummins Data Scientist: Neurodiversity Hiring Initiative
# Job number  133 added - Data Scientist
# Job number  134 added - Data Scientist - NLP
# Job number  135 added - Software Engineer III, AI/ML Threat Predictions (Remote)
# Job number  136 added - Data Scientist, Product Optimization
# Job number  137 added - Data Scientist, Product Analytics
# Job number  138 added - Senior Data Analyst
# Job number  139 added - Data Scientist
# Job number  140 added - Data Analyst
# Job number  141 added - Data Scientist I
# Job number  142 added - Principal Product Data Scientist
# Job number  143 added - Data Scientist
# Job number  144 added - Data Scientist I (Remote)
# Job number  145 added - Senior Data Scientist (Remote)
# Job number  146 added - Data Scientist
# Job number  147 added - Software Engineer III, AI/ML Threat Predictions (Remote)
# Job number  148 added - Applied Scientist - Text-To-Speech (TTS)
# Job number  149 added - Data Scientist II
# Job number  150 added - Data Scientist - 100% Remote

# %%
driver.quit()

# %% [markdown]
# ### Scrape full job descriptions

# %%
Links_list = dataframe['Links'].tolist()
#Links_list

# %%
import random
import time

# %%
descriptions=[]
driver = webdriver.Firefox(executable_path=driver_path, options=options)
for i in Links_list:
    driver.get(i)
    driver.implicitly_wait(random.randint(3, 8))
    jd = driver.find_element(By.XPATH, '//div[@id="jobDescriptionText"]').text
    descriptions.append(jd)
    time.sleep(random.randint(5,10))

dataframe['Descriptions'] = descriptions
# Out:
# C:\Users\shiva\AppData\Local\Temp\ipykernel_28212\1236259918.py:2: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Firefox(executable_path=driver_path, options=options)

# %%
driver.quit()

# %% [markdown]
# ### Save results

# %%
# Convert the dataframe to a csv file
date = datetime.today().strftime('%Y-%m-%d')
dataframe.to_csv(date + "_" + position + "_" + locations + ".csv", index=False)

# %%
dataframe
# Out:
#                                                  Title  \
# 0                                       Data Scientist
# 1          Data Scientist, Marketing & Online (Remote)
# 2                                 Data Scientist - NLP
# 3                         Data Scientist - Telecommute
# 4                                   Jr. Data Scientist
# ..                                                 ...
# 145                                     Data Scientist
# 146  Software Engineer III, AI/ML Threat Prediction...
# 147           Applied Scientist - Text-To-Speech (TTS)
# 148                                  Data Scientist II
# 149                       Data Scientist - 100% Remote
#
#                          Company                           Location Rating  \
# 0    Shaw Industries Group, Inc.                             Remote    3.8
# 1                 The Home Depot        Remote in Atlanta, GA 30361    3.7
# 2                    Ursus, Inc.     Remote in Menlo Park, CA 94025    4.9
# 3             UnitedHealth Group   Remote in Eden Prairie, MN 55344    3.6
# 4                     AffixITPro                             Remote    NaN
# ..                           ...                                ...    ...
# 145                  PocketPills  Remote in San Francisco, CA 94103    NaN
# 146            CrowdStrike, Inc.      Remote in Hempstead, NY 11551    3.3
# 147                     Veritone             Remote in New York, NY    3.1
# 148                   Tek Ninjas        Remote in Seattle, WA 98101    NaN
# 149           Paramount Pictures                             Remote    NaN
#
#                           Date                      Salary  \
# 0      PostedPosted 3 days ago                         NaN
# 1     PostedPosted 11 days ago   $90,000 - $160,000 a year
# 2      PostedPosted 2 days ago     $40.00 - $48.65 an hour
# 3      PostedPosted 6 days ago                         NaN
# 4                  PostedToday           $30 - $40 an hour
# ..                         ...                         ...
# 145  PostedPosted 30+ days ago                         NaN
# 146    PostedPosted 5 days ago  $120,000 - $190,000 a year
# 147     PostedPosted 1 day ago             $140,000 a year
# 148    PostedPosted 9 days ago                         NaN
# 149  EmployerActive 2 days ago                         NaN
#
#                                            Description  \
# 0    Partner with data scientists across the enterp...
# 1    55% Solution Development - Design and develop ...
# 2    Apply knowledge of statistics, machine learnin...
# 3    Work alongside other data scientists, engineer...
# 4    The Data Scientist supports the development of...
# ..                                                 ...
# 145  Proven ability to tailor data-driven insights ...
# 146  Understanding data structures and commands for...
# 147  Mental health awareness and support.\nThis pos...
# 148  Ability to process large sets of data, and cre...
# 149  2+ years of experience in a data analytics or ...
#
#                                                  Links  \
# 0    https://www.indeed.com/pagead/clk?mo=r&ad=-6NY...
# 1    https://www.indeed.com/pagead/clk?mo=r&ad=-6NY...
# 2    https://www.indeed.com/pagead/clk?mo=r&ad=-6NY...
# 3    https://www.indeed.com/pagead/clk?mo=r&ad=-6NY...
# 4    https://www.indeed.com/company/AffixITPro/jobs...
# ..                                                 ...
# 145  https://www.indeed.com/rc/clk?jk=ae6e092dd67f3...
# 146  https://www.indeed.com/pagead/clk?mo=r&ad=-6NY...
# 147  https://www.indeed.com/rc/clk?jk=4514adbc3a77c...
# 148  https://www.indeed.com/rc/clk?jk=e8ccf157fe743...
# 149  https://www.indeed.com/company/Gloss-Genius/jo...
#
#                                           Descriptions
# 0    We are looking for a data scientist to join ou...
# 1    Position Purpose:\nThe Data Scientist is respo...
# 2    JOB TITLE: Data Scientist - NLP\nLOCATION: Rem...
# 3    Combine two of the fastest-growing fields on t...
# 4    Job Description\nAffixIT Pro has been awarded ...
# ..                                                 ...
# 145  Company Description\nPocketPills is a tech-dri...
# 146  About the Role:\nCrowdstrike’s Proactive Secur...
# 147  WE ARE VERITONE\nWe are driven by the belief t...
# 148  Data Scientist II | One-year contract\nHelp us...
# 149  Job Description:\nUnder the mentorship of the ...
#
# [150 rows x 9 columns]
